# %%
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
import numpy as np 
import pandas as pd 
import skimage, os
from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.misc
import numpy as np
from glob import glob
from skimage.io import imread
from livelossplot import PlotLossesKerasTF
from functools import *
import elasticdeform

import random
os.environ["CUDA_VISIBLE_DEVICES"]='1'

BASE_IMG_PATH=os.path.join('hecktor-master','data','resampled')
BATCH_SIZE = 3
INPUT_SHAPE = (144,144,144,2)
PROJECT_NAME = 'hector'
AUG_RATE = 0.4


random.seed(42)
random_seed = 42

AUGMENTATION_OPS = [
    lambda t: np.rot90(t, axes=(1, 2), k=1),  # 90 degree rotation
    lambda t: np.rot90(t, axes=(1, 2), k=2),  # 180 degree rotation
    lambda t: np.rot90(t, axes=(1, 2), k=3),  # 270 degree rotation
    lambda t: np.flip(t, axis=0),  # Axial flip
    lambda t: np.flip(t, axis=1),  # Sagittal flip
    lambda t: np.flip(t, axis=2)  # Coronal flip
]

# %%
glob(os.path.join(BASE_IMG_PATH,'*'))
# Out:
# ['hecktor-master/data/resampled/CHGJ073_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ035_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ082_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS069_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ083_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS052_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM047_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ025_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS041_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS097_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS046_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS055_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR013_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS015_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM027_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS015_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ053_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS098_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ086_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM001_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ090_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS087_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS065_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS068_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS056_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ065_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM026_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ032_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ030_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM006_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM016_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ070_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ032_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ058_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS016_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR024_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS039_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM064_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ008_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ067_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS101_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS016_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ074_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM060_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS078_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS090_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ057_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ030_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS053_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS051_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ090_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS090_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM049_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ069_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM040_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM017_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ048_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ029_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM041_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ036_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM036_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS006_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM046_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS068_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM030_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM023_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR016_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS009_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS048_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ065_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM039_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ062_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS068_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM059_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM027_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR025_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM044_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR016_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ038_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS008_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ091_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM065_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS067_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR029_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM053_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM054_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS041_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS019_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ017_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM033_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR034_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR001_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM015_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ007_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ007_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM024_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS081_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM058_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM016_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM012_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS100_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ050_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM006_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ016_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ039_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ088_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS027_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM019_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS094_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ026_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS036_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ034_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM045_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM013_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ052_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ074_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS005_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM029_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS055_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS060_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM035_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM048_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ034_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM047_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS042_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ031_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM035_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ072_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS049_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS013_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ026_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ034_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM041_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ046_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS069_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR025_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS026_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS096_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS039_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS008_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS046_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS005_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ057_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS049_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ081_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS047_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR021_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ088_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM060_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ081_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ082_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ092_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS007_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS080_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS009_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ073_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR029_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM038_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM029_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR024_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ080_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS031_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ015_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS052_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS056_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ035_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS076_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ017_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS033_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ074_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM038_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS098_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS077_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ070_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS078_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS081_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ088_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM032_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM021_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM014_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM014_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR030_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM051_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM017_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS065_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM007_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM063_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS061_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS038_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM021_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ066_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM055_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS047_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS019_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM056_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM007_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM062_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS003_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS087_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR011_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS007_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS031_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS086_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS026_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ058_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR030_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ092_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ043_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS020_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ087_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS085_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ052_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS028_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ015_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM050_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS058_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ037_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS100_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM056_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM058_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ077_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM019_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM008_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM023_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ071_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS040_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ046_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM022_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS015_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS030_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ038_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ055_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ008_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS020_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ066_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR040_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ071_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS010_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS058_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS066_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS039_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM029_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM056_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM024_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM026_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS064_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM034_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS073_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS031_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS022_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM047_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS101_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ076_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM045_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ090_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR028_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR021_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS043_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ010_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM010_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM022_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS045_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS035_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM042_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS022_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS088_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR020_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR005_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR004_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS045_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS085_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS009_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM037_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ066_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ055_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM039_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM049_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ080_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS091_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM001_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS088_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS036_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM036_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM001_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR013_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS091_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM008_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM064_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM040_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS060_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR025_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS067_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ050_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM044_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS095_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM044_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS043_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM018_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ035_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM043_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS064_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ018_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS033_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS013_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS050_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM032_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ069_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ013_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS046_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS008_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM034_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ069_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM060_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS074_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR023_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM048_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR005_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS005_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM051_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ077_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ078_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS021_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM018_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM055_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ036_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR024_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM011_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS010_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS049_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ013_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS035_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS057_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS097_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ086_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ072_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM065_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM014_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR012_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM015_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS003_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS065_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM017_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS074_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS048_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR020_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ017_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS095_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS048_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS027_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ083_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS074_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS033_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM059_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR023_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM046_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ031_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ037_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS030_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR040_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS096_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS050_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS013_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ016_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ078_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM049_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM038_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ050_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM048_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS057_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM062_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS077_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ062_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS030_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR021_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM045_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS083_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ036_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR005_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS052_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM010_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM019_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM061_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS021_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS088_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR012_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS026_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS083_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ087_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR040_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM053_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ029_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM037_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ026_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ070_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR028_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS042_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ089_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS041_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM036_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM055_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM051_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS040_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS021_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ081_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM027_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ053_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM022_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS066_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS004_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ008_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS004_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS060_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS100_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ086_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS096_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM058_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM050_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM030_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS077_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM057_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS098_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR011_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM053_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS095_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS051_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR012_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ092_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM012_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ048_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ046_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS101_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS006_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS094_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM024_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS073_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS020_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS007_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS087_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM042_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS089_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS078_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS043_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM057_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR014_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS085_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS089_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM034_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR004_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ085_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ032_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM023_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM007_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS056_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ058_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS076_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM035_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM062_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ028_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR004_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS091_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ089_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM011_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ018_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS038_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ076_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ048_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM061_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS081_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR011_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM011_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM030_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS058_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS019_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR013_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS076_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM059_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM039_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ083_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR030_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM037_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ030_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM043_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ055_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR014_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM016_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ052_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS036_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS010_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS055_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR034_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ037_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ025_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS003_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM012_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ053_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM015_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ091_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM046_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR001_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS069_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM013_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ031_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS080_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS086_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ076_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM063_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM033_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ015_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ085_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS073_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS089_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM013_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS066_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ016_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS006_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS040_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS038_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS035_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM010_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR034_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM064_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ039_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS053_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS045_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS004_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM006_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM033_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ071_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ085_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM041_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM057_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR016_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR029_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM043_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM021_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ025_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHMR014_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ018_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ077_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS064_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS042_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS090_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ057_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS016_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR020_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ029_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS083_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ087_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS027_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM002_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ039_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ080_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS097_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM040_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM054_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS086_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM050_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS061_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS053_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS050_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS028_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ007_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM061_ct.nii.gz',
#  'hecktor-master/data/resampled/CHMR023_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ067_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS028_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ043_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ028_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM008_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ082_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM063_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS051_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS094_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM042_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUS061_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS047_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ091_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ065_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ028_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ089_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ067_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS057_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ038_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM026_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUS067_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ010_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM002_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM018_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR001_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ013_pt.nii.gz',
#  'hecktor-master/data/resampled/CHMR028_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ078_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ072_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS080_ct.nii.gz',
#  'hecktor-master/data/resampled/CHUM002_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM065_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUM054_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHUS022_pt.nii.gz',
#  'hecktor-master/data/resampled/CHUM032_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ043_ct.nii.gz',
#  'hecktor-master/data/resampled/CHGJ062_ct_gtvt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ010_pt.nii.gz',
#  'hecktor-master/data/resampled/CHGJ073_ct_gtvt.nii.gz']

# %%
# show some of the files
all_ct_images= glob(os.path.join(BASE_IMG_PATH,'*ct.nii.gz'))
all_pt_images = [x.replace('ct.nii.gz', 'pt.nii.gz') for x in all_ct_images]
all_mask_images = [x.replace('ct.nii.gz', 'ct_gtvt.nii.gz') for x in all_ct_images]
np.random.seed(42)
rand_index = np.random.randint(0, len(all_ct_images))
print(len(all_ct_images),' matching files found:',all_ct_images[rand_index], all_pt_images[rand_index])
print(len(all_mask_images),' matching files found:',all_ct_images[rand_index], all_mask_images[rand_index])
# Out:
# 201  matching files found: hecktor-master/data/resampled/CHUS074_ct.nii.gz hecktor-master/data/resampled/CHUS074_pt.nii.gz
# 201  matching files found: hecktor-master/data/resampled/CHUS074_ct.nii.gz hecktor-master/data/resampled/CHUS074_ct_gtvt.nii.gz

# %%
# %matplotlib inline
try:
    import nibabel as nib
except:
    raise ImportError('Install NIBABEL')
    
test_ct=np.asarray(nib.load(all_ct_images[rand_index]).dataobj)
test_pt=np.asarray(nib.load(all_pt_images[rand_index]).dataobj)
test_mask=np.asarray(nib.load(all_mask_images[rand_index]).dataobj)
print(test_ct.shape)

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (12, 6))

ax1.imshow(test_ct[test_ct.shape[0]//2], cmap = 'gray')
ax1.set_title('CT')
ax2.imshow(test_pt[test_pt.shape[0]//2], cmap = 'gray')
ax2.set_title('PT')
ax3.imshow(test_mask[test_mask.shape[0]//2], cmap = 'gray')
ax3.set_title('Mask')
# Out:
# (144, 144, 144)
# Text(0.5, 1.0, 'Mask')

# %%
def make144(image):
    new_image = image[:144,:144,:144]
    return new_image

def preprocess(image):
    if image.shape != (144,144,144):
        image = make144(image)
    new_image = (image - image.mean())/image.std()
    
    return new_image
print(test_pt.max(), test_pt.min(),test_pt.shape)
new_img = preprocess(test_pt)
print(new_img.max(), new_img.min(),new_img.shape)
# Out:
# 12.489239 -0.0050189 (144, 144, 144)
# 9.617565 -0.9385557 (144, 144, 144)

# %%
data = preprocess(test_pt)
data = np.concatenate((data, preprocess(test_pt)), -1)
data.shape
# Out:
# (144, 144, 288)

# %%
#check if ct, pt, mask have same numbers.

from sklearn.model_selection import train_test_split

if not len(all_ct_images) == len(all_pt_images) == len(all_mask_images):
    print(len(all_ct_images), len(all_pt_images), len(all_mask_images))
    raise ValueError('ct,pt,mask number not match')

data_list_index = range(len(all_ct_images))
train_data_list, val_data_list = train_test_split(data_list_index, test_size = 0.2, random_state = 42)

# %%
from functools import *

def get_augment_operations(random_state, probability=.25):
    """
    Return a function that can be applied for augmenting a tensor.
    Included operations are:
        - flipping (axial, sagittal and coronal);
        - rotation (90, 180 and 720).
    Each of the six operations has a certain probability to be included for 
    augmentation.
    :param random_state: random state.
    :param probability: probability for operation inclusion.
    :return: function to apply to tensor.
    """
    probabilities = random_state.uniform(size=len(AUGMENTATION_OPS))
    operations = [
        f for p, f in zip(probabilities, AUGMENTATION_OPS) if p > probability
    ]

    def _wrapped(x):
        augmented = reduce(lambda t, f: f(t), operations, x)
        assert augmented.shape == x.shape
        return augmented

    return _wrapped

# Augment
#f = get_augment_operations(random_state, augment_probability)
#x = f(x)
#y = f(y)

# %%
# Augment test

random_state = np.random.RandomState()
f = get_augment_operations(random_state)

_aug_test_ct = f(test_ct)
_aug_test_pt = f(test_pt)
_aug_test_mask = f(test_mask)
_aug_test_ct[_aug_test_ct<-150]=-150
_aug_test_ct[_aug_test_ct>150]=150

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (12, 6))

ax1.imshow(_aug_test_ct[_aug_test_ct.shape[0]//2], cmap = 'gray')
ax1.set_title('CT')
ax2.imshow(_aug_test_pt[_aug_test_pt.shape[0]//2], cmap = 'gray')
ax2.set_title('PT')
ax3.imshow(_aug_test_mask[_aug_test_mask.shape[0]//2], cmap = 'gray')
ax3.set_title('Mask')
plt.show()

# %%
import tensorflow as tf
import random
from scipy.ndimage import zoom
def tf_data_generator(file_list, batch_size = 2, augment_rate = 0):

    i = 0
    j = 0
    if augment_rate!=0:
        #if we want to augmenation
        k = int(len(file_list) * augment_rate)
        indicies = random.sample(range(len(file_list)), k)
        aug_list = [file_list[i] for i in indicies]
            
    while True:
        if i*batch_size >= (len(file_list) * (1 + augment_rate)): 
            #start again
            i = 0
            j = 0
            np.random.shuffle(file_list)
            if augment_rate!=0:
                #if we want to augmenation
                k = int(len(file_list) * augment_rate)
                indicies = random.sample(range(len(file_list)), k)
                aug_list = [file_list[i] for i in indicies]
        if augment_rate != 0 and i*batch_size >= len(file_list):  
            #augmentation
            # if data in augmentation list 
            file_chunk = aug_list[j*batch_size:(j+1)*batch_size] 
            data = []
            labels = []
            for file in file_chunk:   
                _ct=np.asarray(nib.load(all_ct_images[file]).dataobj)
                _pt=np.asarray(nib.load(all_pt_images[file]).dataobj)
                _mask=np.asarray(nib.load(all_mask_images[file]).dataobj)
                _ct[_ct<-150] = -150
                _ct[_ct>150] = 150

                _ct = preprocess(_ct)
                _pt = preprocess(_pt)
                _mask = make144(_mask)
                #print(_ct.shape, _pt.shape, _mask.shape)              
                if i % 2 == 0 :
                    #elastic deformation
                    num1, num2 = sorted(random.sample(set([0, 1, 2]), 2))
                    [_ct, _pt, _mask] = elasticdeform.deform_random_grid([_ct, _pt, _mask] , sigma=3, points=4, 
                                                                      axis=[(num1, num2), (num1, num2), (num1, num2)])            
                #if i % 3 == 0:
                #    r = random.randrange(10, 13, 1)
                #    r = r/10
                #    _ct = make144(zoom(_ct, (r, r, r), mode = 'nearest'))
                #    _pt = make144(zoom(_pt, (r, r, r), mode = 'nearest'))
                #    _mask = make144(zoom(_mask, (r, r, r), mode = 'nearest'))
                #    
                #_mask[_mask<0.5] = 0 
                #_mask[_mask >= 0.5] = 1
                #
                #img = np.concatenate((_ct[..., np.newaxis], _pt[..., np.newaxis]), -1)
                #
                #if i % 1 == 0 :
                #    #print("rotation, flip deformation")
                #    #rotation, flip augmentation
                #    random_state = np.random.RandomState()
                #    f = get_augment_operations(random_state)
                #    img = f(img)
                #    _mask = f(_mask)
            
                data.append(img) 
                #binarization again for deformated masks.

                labels.append(_mask)
                
            data = np.asarray(data)
            labels = np.asarray(labels)
            yield data, labels
            i = i + 1
            j = j + 1

        else:
            file_chunk = file_list[i*batch_size:(i+1)*batch_size] 
            data = []
            labels = []
            for file in file_chunk:
                _ct=np.asarray(nib.load(all_ct_images[file]).dataobj)
                _pt=np.asarray(nib.load(all_pt_images[file]).dataobj)
                _mask=np.asarray(nib.load(all_mask_images[file]).dataobj)

                _ct[_ct<-150] = -150
                _ct[_ct>150] =150
                
                _ct = preprocess(_ct)
                _pt = preprocess(_pt)
                
                img = np.concatenate((_ct[..., np.newaxis], _pt[..., np.newaxis]), -1)
                
                data.append(img) 
                _mask = make144(_mask)
                
                labels.append(_mask)
                
            data = np.asarray(data)
            labels = np.asarray(labels)
            yield data, labels
            i = i + 1
            
batch_size = BATCH_SIZE
augment_rate = AUG_RATE
#tf_data_generator(train_data_list)


train_dataset = tf.data.Dataset.from_generator(tf_data_generator,args= [train_data_list, batch_size, augment_rate],
                                         output_types = (tf.float32, tf.float32),
                                         output_shapes = ((None,144,144,144,2),(None,144,144,144)))        

valid_dataset = tf.data.Dataset.from_generator(tf_data_generator,args= [val_data_list, batch_size],
                                         output_types = (tf.float32, tf.float32),
                                         output_shapes = ((None,144,144,144,2),(None,144,144,144))) 

#test the data generator
num = 0
for data, labels in train_dataset:
    print(data.shape, labels.shape)
    print(labels.shape)
    num = num + 1
    if num > 7: break
print("testing valid pipeline")  
for data, labels in valid_dataset:
    print(data.shape, labels.shape)

    num = num + 1
    if num > 0: break
# Out:
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# (3, 144, 144, 144, 2) (3, 144, 144, 144)
# (3, 144, 144, 144)
# testing valid pipeline
# (3, 144, 144, 144, 2) (3, 144, 144, 144)

# %%
r = random.randrange(8, 12, 1)
r/10
# Out:
# 0.8

# %% [markdown]
# ## Densely 3D Unet

# %%
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, add, multiply
from tensorflow.keras.optimizers import Adam


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, MaxPooling3D
from tensorflow.keras.layers import Conv3D, Conv3DTranspose
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation, Dropout
from tensorflow.keras.layers import concatenate
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2


def denseBlock(t, nb_layers):
    for _ in range(nb_layers):
        tmp = t
        t = BatchNormalization(axis=1,
                                gamma_regularizer=l2(0.0001),
                                beta_regularizer=l2(0.0001))(t)

        t = Activation('relu')(t)
        t = Conv3D(16, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_uniform', data_format='channels_last')(t)
        t = Dropout(0.2)(t)
        t = concatenate([t, tmp])
    return t

def transitionDown(t, nb_features):
    t = BatchNormalization(axis=1,
                            gamma_regularizer=l2(0.0001),
                            beta_regularizer=l2(0.0001))(t)
    t = Activation('relu')(t)
    t = Conv3D(nb_features, kernel_size=(1, 1, 1), padding='same', kernel_initializer='he_uniform', data_format='channels_last')(t)
    t = Dropout(0.2)(t)
    #t = MaxPooling3D(pool_size=(2, 2, 2), strides=2, padding='same', data_format='channels_last')(t)
    t = Conv3D(nb_features, kernel_size=(1, 1, 1),strides=(2,2,1), padding='same', data_format='channels_last')(t)
    
    return t

def Tiramisu3D(layer_per_block, n_pool=4, growth_rate=16):
    input_layer = Input(shape=INPUT_SHAPE)
    t = Conv3D(48, kernel_size=(3, 3, 3), strides=(1, 1, 1), padding='same')(input_layer)

    #dense block
    nb_features = 48
    skip_connections = []
    for i in range(n_pool):
        t = denseBlock(t, layer_per_block[i])
        skip_connections.append(t)
        nb_features += growth_rate * layer_per_block[i]
        t = transitionDown(t, nb_features)

    t = denseBlock(t, layer_per_block[n_pool]) # bottle neck

    skip_connections = skip_connections[::-1] #subvert the array

    for i in range(n_pool):
        keep_nb_features = growth_rate * layer_per_block[n_pool + i]
        t = Conv3DTranspose(keep_nb_features, strides=(2,2,1), kernel_size=(3, 3, 3), padding='same', data_format='channels_last')(t) # transition Up
        t = concatenate([t, skip_connections[i]])

        t = denseBlock(t, layer_per_block[n_pool+i+1])

    t = Conv3D(12, kernel_size=(1, 1, 1), padding='same', kernel_initializer='he_uniform', data_format='channels_last')(t)
    output_layer = Activation('softmax')(t)
    return Model(inputs=input_layer, outputs=output_layer)

layer_per_block =  [3, 4, 5, 6, 7, 6, 5, 4, 3]
#layer_per_block = [4, 5, 7, 10, 12, 15, 12, 10, 7, 5, 4]
tiramisu = Tiramisu3D(layer_per_block)

tiramisu.summary()
#plot_model(model, to_file='model.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 144, 144, 14 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 144, 144, 144 2640        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 144, 144, 144 576         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 144, 144, 144 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 144, 144, 144 20752       activation[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 144, 144, 144 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 144, 144, 144 0           dropout[0][0]
#                                                                  conv3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 144, 144, 144 576         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 144, 144, 144 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 144, 144, 144 27664       activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 144, 144, 144 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 144, 144, 144 0           dropout_1[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 144, 144, 144 576         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 144, 144, 144 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 144, 144, 144 34576       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 144, 144, 144 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 144, 144, 144 0           dropout_2[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 144, 144, 144 576         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 144, 144, 144 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 144, 144, 144 9312        activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 144, 144, 144 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 72, 72, 144,  9312        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 72, 72, 144,  288         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 72, 72, 144,  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 72, 72, 144,  41488       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 72, 72, 144,  0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 72, 72, 144,  0           dropout_4[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 72, 72, 144,  288         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 72, 72, 144,  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 72, 72, 144,  48400       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 72, 72, 144,  0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 72, 72, 144,  0           dropout_5[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 72, 72, 144,  288         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 72, 72, 144,  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 72, 72, 144,  55312       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 72, 72, 144,  0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 72, 72, 144,  0           dropout_6[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 72, 72, 144,  288         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 72, 72, 144,  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 72, 72, 144,  62224       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 72, 72, 144,  0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 72, 72, 144,  0           dropout_7[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 72, 72, 144,  288         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 72, 72, 144,  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 72, 72, 144,  25760       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 72, 72, 144,  0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 36, 36, 144,  25760       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 36, 36, 144,  144         conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 36, 36, 144,  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 36, 36, 144,  69136       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 36, 36, 144,  0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 36, 36, 144,  0           dropout_9[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 36, 36, 144,  144         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 36, 36, 144,  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 36, 36, 144,  76048       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 36, 36, 144,  0           conv3d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 36, 36, 144,  0           dropout_10[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 36, 36, 144,  144         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 36, 36, 144,  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 36, 36, 144,  82960       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 36, 36, 144,  0           conv3d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 36, 36, 144,  0           dropout_11[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 36, 36, 144,  144         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 36, 36, 144,  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 36, 36, 144,  89872       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 36, 36, 144,  0           conv3d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 36, 36, 144,  0           dropout_12[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 36, 36, 144,  144         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 36, 36, 144,  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 36, 36, 144,  96784       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 36, 36, 144,  0           conv3d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 36, 36, 144,  0           dropout_13[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 36, 36, 144,  144         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 36, 36, 144,  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 36, 36, 144,  57840       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 36, 36, 144,  0           conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 18, 18, 144,  57840       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 18, 18, 144,  72          conv3d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 18, 18, 144,  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 18, 18, 144,  103696      activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 18, 18, 144,  0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 18, 18, 144,  0           dropout_15[0][0]
#                                                                  conv3d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 18, 18, 144,  72          concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 18, 18, 144,  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 18, 18, 144,  110608      activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 18, 18, 144,  0           conv3d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 18, 18, 144,  0           dropout_16[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 18, 18, 144,  72          concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 18, 18, 144,  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 18, 18, 144,  117520      activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 18, 18, 144,  0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 18, 18, 144,  0           dropout_17[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 18, 18, 144,  72          concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 18, 18, 144,  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 18, 18, 144,  124432      activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 18, 18, 144,  0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 18, 18, 144,  0           dropout_18[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 18, 18, 144,  72          concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 18, 18, 144,  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 18, 18, 144,  131344      activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 18, 18, 144,  0           conv3d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 18, 18, 144,  0           dropout_19[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 18, 18, 144,  72          concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 18, 18, 144,  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 18, 18, 144,  138256      activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 18, 18, 144,  0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 18, 18, 144,  0           dropout_20[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 18, 18, 144,  72          concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 18, 18, 144,  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 18, 18, 144,  113232      activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 18, 18, 144,  0           conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 9, 9, 144, 33 113232      dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 9, 9, 144, 33 36          conv3d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 9, 9, 144, 33 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 9, 9, 144, 16 145168      activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 9, 9, 144, 35 0           dropout_22[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 9, 9, 144, 35 36          concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 9, 9, 144, 35 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 9, 9, 144, 16 152080      activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 9, 9, 144, 36 0           dropout_23[0][0]
#                                                                  concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 9, 9, 144, 36 36          concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 9, 9, 144, 36 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 9, 9, 144, 16 158992      activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 9, 9, 144, 38 0           dropout_24[0][0]
#                                                                  concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 9, 9, 144, 38 36          concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 9, 9, 144, 38 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 9, 9, 144, 16 165904      activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 9, 9, 144, 40 0           dropout_25[0][0]
#                                                                  concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 9, 9, 144, 40 36          concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 9, 9, 144, 40 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 9, 9, 144, 16 172816      activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 9, 9, 144, 41 0           dropout_26[0][0]
#                                                                  concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 9, 9, 144, 41 36          concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 9, 9, 144, 41 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 9, 9, 144, 16 179728      activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 9, 9, 144, 43 0           dropout_27[0][0]
#                                                                  concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 9, 9, 144, 43 36          concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 9, 9, 144, 43 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 9, 9, 144, 16 186640      activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 9, 9, 144, 16 0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 9, 9, 144, 44 0           dropout_28[0][0]
#                                                                  concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 18, 18, 144,  1354864     concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 18, 18, 144,  0           conv3d_transpose[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 18, 18, 144,  72          concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 18, 18, 144,  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 18, 18, 144,  193552      activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 18, 18, 144,  0           conv3d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 18, 18, 144,  0           dropout_29[0][0]
#                                                                  concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 18, 18, 144,  72          concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 18, 18, 144,  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 18, 18, 144,  200464      activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 18, 18, 144,  0           conv3d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 18, 18, 144,  0           dropout_30[0][0]
#                                                                  concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 18, 18, 144,  72          concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 18, 18, 144,  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 18, 18, 144,  207376      activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 18, 18, 144,  0           conv3d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 18, 18, 144,  0           dropout_31[0][0]
#                                                                  concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 18, 18, 144,  72          concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 18, 18, 144,  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 18, 18, 144,  214288      activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 18, 18, 144,  0           conv3d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 18, 18, 144,  0           dropout_32[0][0]
#                                                                  concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 18, 18, 144,  72          concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 18, 18, 144,  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 18, 18, 144,  221200      activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 18, 18, 144,  0           conv3d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 18, 18, 144,  0           dropout_33[0][0]
#                                                                  concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 18, 18, 144,  72          concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 18, 18, 144,  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 18, 18, 144,  228112      activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 18, 18, 144,  0           conv3d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 18, 18, 144,  0           dropout_34[0][0]
#                                                                  concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 36, 36, 144,  1410144     concatenate_31[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 36, 36, 144,  0           conv3d_transpose_1[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 36, 36, 144,  144         concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 36, 36, 144,  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 36, 36, 144,  145168      activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 36, 36, 144,  0           conv3d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 36, 36, 144,  0           dropout_35[0][0]
#                                                                  concatenate_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 36, 36, 144,  144         concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 36, 36, 144,  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 36, 36, 144,  152080      activation_36[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 36, 36, 144,  0           conv3d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 36, 36, 144,  0           dropout_36[0][0]
#                                                                  concatenate_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 36, 36, 144,  144         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 36, 36, 144,  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 36, 36, 144,  158992      activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 36, 36, 144,  0           conv3d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 36, 36, 144,  0           dropout_37[0][0]
#                                                                  concatenate_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 36, 36, 144,  144         concatenate_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 36, 36, 144,  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 36, 36, 144,  165904      activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 36, 36, 144,  0           conv3d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 36, 36, 144,  0           dropout_38[0][0]
#                                                                  concatenate_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 36, 36, 144,  144         concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 36, 36, 144,  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 36, 36, 144,  172816      activation_39[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 36, 36, 144,  0           conv3d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 36, 36, 144,  0           dropout_39[0][0]
#                                                                  concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 72, 72, 144,  898640      concatenate_37[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 72, 72, 144,  0           conv3d_transpose_2[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 72, 72, 144,  288         concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 72, 72, 144,  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 72, 72, 144,  103696      activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 72, 72, 144,  0           conv3d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 72, 72, 144,  0           dropout_40[0][0]
#                                                                  concatenate_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 72, 72, 144,  288         concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 72, 72, 144,  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 72, 72, 144,  110608      activation_41[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 72, 72, 144,  0           conv3d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 72, 72, 144,  0           dropout_41[0][0]
#                                                                  concatenate_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 72, 72, 144,  288         concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 72, 72, 144,  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 72, 72, 144,  117520      activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 72, 72, 144,  0           conv3d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 72, 72, 144,  0           dropout_42[0][0]
#                                                                  concatenate_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 72, 72, 144,  288         concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 72, 72, 144,  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv3d_48 (Conv3D)              (None, 72, 72, 144,  124432      activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 72, 72, 144,  0           conv3d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 72, 72, 144,  0           dropout_43[0][0]
#                                                                  concatenate_41[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 144, 144, 144 525376      concatenate_42[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 144, 144, 144 0           conv3d_transpose_3[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 144, 144, 144 576         concatenate_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 144, 144, 144 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv3d_49 (Conv3D)              (None, 144, 144, 144 69136       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 144, 144, 144 0           conv3d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 144, 144, 144 0           dropout_44[0][0]
#                                                                  concatenate_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 144, 144, 144 576         concatenate_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 144, 144, 144 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 144, 144, 144 76048       activation_45[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 144, 144, 144 0           conv3d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 144, 144, 144 0           dropout_45[0][0]
#                                                                  concatenate_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 144, 144, 144 576         concatenate_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 144, 144, 144 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 144, 144, 144 82960       activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 144, 144, 144 0           conv3d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 144, 144, 144 0           dropout_46[0][0]
#                                                                  concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 144, 144, 144 2508        concatenate_46[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 144, 144, 144 0           conv3d_52[0][0]
# ==================================================================================================
# Total params: 9,952,608
# Trainable params: 9,947,910
# Non-trainable params: 4,698
# __________________________________________________________________________________________________

# %% [markdown]
# # Attention gate input

# %%
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, add, multiply
from tensorflow.keras.optimizers import Adam


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, MaxPooling3D
from tensorflow.keras.layers import Conv3D, Conv3DTranspose
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation, Dropout
from tensorflow.keras.layers import concatenate
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2

PROJECT_NAME = 'hector_attention_gate'
project_name = PROJECT_NAME

def attention_block_3d(x, g, inter_channel, data_format='channels_last'):
    # theta_x(?,g_height,g_width,inter_channel)

    theta_x = Conv3D(inter_channel, [1, 1, 1], strides=[1, 1, 1], data_format=data_format)(x)

    # phi_g(?,g_height,g_width,inter_channel)

    phi_g = Conv3D(inter_channel, [1, 1, 1], strides=[1, 1, 1], data_format=data_format)(g)

    # f(?,g_height,g_width,inter_channel)

    f = Activation('relu')(add([theta_x, phi_g]))

    # psi_f(?,g_height,g_width,1)

    psi_f = Conv3D(1, [1, 1, 1], strides=[1, 1, 1], data_format=data_format)(f)

    rate = Activation('sigmoid')(psi_f)

    # rate(?,x_height,x_width)

    # att_x(?,x_height,x_width,x_channel)

    att_x = multiply([x, rate])

    return att_x

# %%
def att_input_unet(att_input= True, inter_channel = 1):
    inputs = Input(INPUT_SHAPE)
    if att_input:
        att = attention_block_3d(inputs[...,0,np.newaxis], inputs[...,1, np.newaxis], inter_channel)
        conv11 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(att)
    else:
        conv11 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(inputs)
        
    conc11 = concatenate([inputs, conv11], axis=4)
    conv12 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(conc11)
    conc12 = concatenate([inputs, conv12], axis=4)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conc12)

    conv21 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(pool1)
    conc21 = concatenate([pool1, conv21], axis=4)
    conv22 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(conc21)
    conc22 = concatenate([pool1, conv22], axis=4)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conc22)

    conv31 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(pool2)
    conc31 = concatenate([pool2, conv31], axis=4)
    conv32 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(conc31)
    conc32 = concatenate([pool2, conv32], axis=4)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conc32)
    
    dropout1 = Dropout(0.5)(pool3)
    conv41 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(dropout1)
    conc41 = concatenate([pool3, conv41], axis=4)
    conv42 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(conc41)
    conc42 = concatenate([pool3, conv42], axis=4)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(conc42)
    
    dropout2 = Dropout(0.5)(pool4)
    conv51 = Conv3D(512, (3, 3, 3), activation='relu', padding='same')(dropout2)
    conc51 = concatenate([pool4, conv51], axis=4)
    conv52 = Conv3D(512, (3, 3, 3), activation='relu', padding='same')(conc51)
    conc52 = concatenate([pool4, conv52], axis=4)

    up6 = concatenate([Conv3DTranspose(256, (2, 2, 2), strides=(2, 2, 2), padding='same')(conc52), conc42], axis=4)
    conv61 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(up6)
    conc61 = concatenate([up6, conv61], axis=4)
    conv62 = Conv3D(256, (3, 3, 3), activation='relu', padding='same')(conc61)
    conc62 = concatenate([up6, conv62], axis=4)

    up7 = concatenate([Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(conc62), conv32], axis=4)
    conv71 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(up7)
    conc71 = concatenate([up7, conv71], axis=4)
    conv72 = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(conc71)
    conc72 = concatenate([up7, conv72], axis=4)

    up8 = concatenate([Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(conc72), conv22], axis=4)
    conv81 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(up8)
    conc81 = concatenate([up8, conv81], axis=4)
    conv82 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(conc81)
    conc82 = concatenate([up8, conv82], axis=4)

    up9 = concatenate([Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(conc82), conv12], axis=4)
    conv91 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(up9)
    conc91 = concatenate([up9, conv91], axis=4)
    conv92 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(conc91)
    conc92 = concatenate([up9, conv92], axis=4)

    conv10 = Conv3D(1, (1, 1, 1), activation='sigmoid')(conc92)

    model = Model(inputs=[inputs], outputs=[conv10])

    model.summary()

    return model

model = att_input_unet(att_input= False, inter_channel = 1)
# Out:
# Model: "model_50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_51 (InputLayer)           [(None, 144, 144, 14 0
# __________________________________________________________________________________________________
# conv3d_984 (Conv3D)             (None, 144, 144, 144 1760        input_51[0][0]
# __________________________________________________________________________________________________
# concatenate_1125 (Concatenate)  (None, 144, 144, 144 0           input_51[0][0]
#                                                                  conv3d_984[0][0]
# __________________________________________________________________________________________________
# conv3d_985 (Conv3D)             (None, 144, 144, 144 29408       concatenate_1125[0][0]
# __________________________________________________________________________________________________
# concatenate_1126 (Concatenate)  (None, 144, 144, 144 0           input_51[0][0]
#                                                                  conv3d_985[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_196 (MaxPooling3D (None, 72, 72, 72, 3 0           concatenate_1126[0][0]
# __________________________________________________________________________________________________
# conv3d_986 (Conv3D)             (None, 72, 72, 72, 6 58816       max_pooling3d_196[0][0]
# __________________________________________________________________________________________________
# concatenate_1127 (Concatenate)  (None, 72, 72, 72, 9 0           max_pooling3d_196[0][0]
#                                                                  conv3d_986[0][0]
# __________________________________________________________________________________________________
# conv3d_987 (Conv3D)             (None, 72, 72, 72, 6 169408      concatenate_1127[0][0]
# __________________________________________________________________________________________________
# concatenate_1128 (Concatenate)  (None, 72, 72, 72, 9 0           max_pooling3d_196[0][0]
#                                                                  conv3d_987[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_197 (MaxPooling3D (None, 36, 36, 36, 9 0           concatenate_1128[0][0]
# __________________________________________________________________________________________________
# conv3d_988 (Conv3D)             (None, 36, 36, 36, 1 338816      max_pooling3d_197[0][0]
# __________________________________________________________________________________________________
# concatenate_1129 (Concatenate)  (None, 36, 36, 36, 2 0           max_pooling3d_197[0][0]
#                                                                  conv3d_988[0][0]
# __________________________________________________________________________________________________
# conv3d_989 (Conv3D)             (None, 36, 36, 36, 1 781184      concatenate_1129[0][0]
# __________________________________________________________________________________________________
# concatenate_1130 (Concatenate)  (None, 36, 36, 36, 2 0           max_pooling3d_197[0][0]
#                                                                  conv3d_989[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_198 (MaxPooling3D (None, 18, 18, 18, 2 0           concatenate_1130[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 18, 18, 18, 2 0           max_pooling3d_198[0][0]
# __________________________________________________________________________________________________
# conv3d_990 (Conv3D)             (None, 18, 18, 18, 2 1562368     dropout_96[0][0]
# __________________________________________________________________________________________________
# concatenate_1131 (Concatenate)  (None, 18, 18, 18, 4 0           max_pooling3d_198[0][0]
#                                                                  conv3d_990[0][0]
# __________________________________________________________________________________________________
# conv3d_991 (Conv3D)             (None, 18, 18, 18, 2 3331840     concatenate_1131[0][0]
# __________________________________________________________________________________________________
# concatenate_1132 (Concatenate)  (None, 18, 18, 18, 4 0           max_pooling3d_198[0][0]
#                                                                  conv3d_991[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_199 (MaxPooling3D (None, 9, 9, 9, 482) 0           concatenate_1132[0][0]
# __________________________________________________________________________________________________
# dropout_97 (Dropout)            (None, 9, 9, 9, 482) 0           max_pooling3d_199[0][0]
# __________________________________________________________________________________________________
# conv3d_992 (Conv3D)             (None, 9, 9, 9, 512) 6663680     dropout_97[0][0]
# __________________________________________________________________________________________________
# concatenate_1133 (Concatenate)  (None, 9, 9, 9, 994) 0           max_pooling3d_199[0][0]
#                                                                  conv3d_992[0][0]
# __________________________________________________________________________________________________
# conv3d_993 (Conv3D)             (None, 9, 9, 9, 512) 13741568    concatenate_1133[0][0]
# __________________________________________________________________________________________________
# concatenate_1134 (Concatenate)  (None, 9, 9, 9, 994) 0           max_pooling3d_199[0][0]
#                                                                  conv3d_993[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_200 (Conv3DTra (None, 18, 18, 18, 2 2035968     concatenate_1134[0][0]
# __________________________________________________________________________________________________
# concatenate_1135 (Concatenate)  (None, 18, 18, 18, 7 0           conv3d_transpose_200[0][0]
#                                                                  concatenate_1132[0][0]
# __________________________________________________________________________________________________
# conv3d_994 (Conv3D)             (None, 18, 18, 18, 2 5101312     concatenate_1135[0][0]
# __________________________________________________________________________________________________
# concatenate_1136 (Concatenate)  (None, 18, 18, 18, 9 0           concatenate_1135[0][0]
#                                                                  conv3d_994[0][0]
# __________________________________________________________________________________________________
# conv3d_995 (Conv3D)             (None, 18, 18, 18, 2 6870784     concatenate_1136[0][0]
# __________________________________________________________________________________________________
# concatenate_1137 (Concatenate)  (None, 18, 18, 18, 9 0           concatenate_1135[0][0]
#                                                                  conv3d_995[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_201 (Conv3DTra (None, 36, 36, 36, 1 1017984     concatenate_1137[0][0]
# __________________________________________________________________________________________________
# concatenate_1138 (Concatenate)  (None, 36, 36, 36, 2 0           conv3d_transpose_201[0][0]
#                                                                  conv3d_989[0][0]
# __________________________________________________________________________________________________
# conv3d_996 (Conv3D)             (None, 36, 36, 36, 1 884864      concatenate_1138[0][0]
# __________________________________________________________________________________________________
# concatenate_1139 (Concatenate)  (None, 36, 36, 36, 3 0           concatenate_1138[0][0]
#                                                                  conv3d_996[0][0]
# __________________________________________________________________________________________________
# conv3d_997 (Conv3D)             (None, 36, 36, 36, 1 1327232     concatenate_1139[0][0]
# __________________________________________________________________________________________________
# concatenate_1140 (Concatenate)  (None, 36, 36, 36, 3 0           concatenate_1138[0][0]
#                                                                  conv3d_997[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_202 (Conv3DTra (None, 72, 72, 72, 6 196672      concatenate_1140[0][0]
# __________________________________________________________________________________________________
# concatenate_1141 (Concatenate)  (None, 72, 72, 72, 1 0           conv3d_transpose_202[0][0]
#                                                                  conv3d_987[0][0]
# __________________________________________________________________________________________________
# conv3d_998 (Conv3D)             (None, 72, 72, 72, 6 221248      concatenate_1141[0][0]
# __________________________________________________________________________________________________
# concatenate_1142 (Concatenate)  (None, 72, 72, 72, 1 0           concatenate_1141[0][0]
#                                                                  conv3d_998[0][0]
# __________________________________________________________________________________________________
# conv3d_999 (Conv3D)             (None, 72, 72, 72, 6 331840      concatenate_1142[0][0]
# __________________________________________________________________________________________________
# concatenate_1143 (Concatenate)  (None, 72, 72, 72, 1 0           concatenate_1141[0][0]
#                                                                  conv3d_999[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_203 (Conv3DTra (None, 144, 144, 144 49184       concatenate_1143[0][0]
# __________________________________________________________________________________________________
# concatenate_1144 (Concatenate)  (None, 144, 144, 144 0           conv3d_transpose_203[0][0]
#                                                                  conv3d_985[0][0]
# __________________________________________________________________________________________________
# conv3d_1000 (Conv3D)            (None, 144, 144, 144 55328       concatenate_1144[0][0]
# __________________________________________________________________________________________________
# concatenate_1145 (Concatenate)  (None, 144, 144, 144 0           concatenate_1144[0][0]
#                                                                  conv3d_1000[0][0]
# __________________________________________________________________________________________________
# conv3d_1001 (Conv3D)            (None, 144, 144, 144 82976       concatenate_1145[0][0]
# __________________________________________________________________________________________________
# concatenate_1146 (Concatenate)  (None, 144, 144, 144 0           concatenate_1144[0][0]
#                                                                  conv3d_1001[0][0]
# __________________________________________________________________________________________________
# conv3d_1002 (Conv3D)            (None, 144, 144, 144 97          concatenate_1146[0][0]
# ==================================================================================================
# Total params: 44,854,337
# Trainable params: 44,854,337
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # learning rate finder, learning rate restart

# %%
#Implementation
#Both finding the optimal range of learning rates and assigning a learning rate schedule can be implemented quite trivially using Keras Callbacks.
#Finding the optimal learning rate range
#We can write a Keras Callback which tracks the loss associated with a learning rate varied linearly over a defined range.
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt

class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''

    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=None, epochs=None):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
    
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')
        
        
        
        
class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau
from livelossplot import PlotLossesKerasTF
from lovaz1 import lovasz_hinge 

project_name = PROJECT_NAME

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())


def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def categorical_focal_loss_fixed(logits, labels, gamma=2., alpha=.25):
    """
    :param logits: A tensor resulting from a softmax
    :param labels: A tensor of the same shape as `logits`
    :input shape: [batch, depth, hight, width, channels]
    :return: Output tensor.
    """

    # Scale predictions so that the class probas of each sample sum to 1
    logits /= K.sum(logits, axis=-1, keepdims=True)

    # Clip the prediction value to prevent NaN's and Inf's
    epsilon = K.epsilon()
    logits = K.clip(logits, epsilon, 1. - epsilon)

    # Calculate Cross Entropy
    cross_entropy = -labels * K.log(logits)

    # Calculate Focal Loss
    loss = alpha * K.pow(1 - logits, gamma) * cross_entropy

    # Sum the losses in mini_batch
#    return K.sum(loss, axis=1)
    return  K.mean(loss)


def hyper_loss(y_true, y_pred):
    return  dice_coef_loss(y_true, y_pred) + categorical_focal_loss_fixed(y_true, y_pred)



def bce_dice_loss(y_true, y_pred):
    return 0.5 * tf.keras.losses.binary_crossentropy(y_true, y_pred) + dice_coef_loss(y_true, y_pred)

def lovaz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(y_true, 'int32'), K.cast(y_pred, 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    
    logits = y_pred 
    loss = lovasz_hinge(logits, y_true, per_image = False, ignore = None)
    return loss

def lovaz_bce_loss(y_true, y_pred):
    return 0.5*tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred) + lovaz_loss(y_true, y_pred))


def dice_lovaz(y_true, y_pred):
    return 0.5*lovaz_loss(y_true, y_pred) + dice_coef_loss(y_true, y_pred)

def train(att_input= True, inter_channel = 1, loss_function= dice_coef_loss, retrain = False, L2 = False):
    batch_size = BATCH_SIZE
    project_name = PROJECT_NAME
    print(project_name)
    print('-'*30)
    print('Creating and compiling model...')
    print('-'*30)
    model = att_input_unet(att_input= att_input, inter_channel = inter_channel)
    weight_dir = 'weights'
    if not os.path.exists(weight_dir):
        os.mkdir(weight_dir)
        
    if retrain != False:
        # It can be used to reconstruct the model identically.
        model = tf.keras.models.load_model(os.path.join(weight_dir,retrain+'.h5'), 
                                           custom_objects={'hyper_loss':hyper_loss,
                                                           'bce_dice_loss': bce_dice_loss,
                                                           'dice_coef': dice_coef,
                                                           'lovaz_loss':lovaz_loss,
                                                           'dice_lovaz':dice_lovaz,
                                                           'lovaz_bce_loss': lovaz_bce_loss,
                                                           'dice_coef_loss': dice_coef_loss})
        
    model_checkpoint = ModelCheckpoint(os.path.join(weight_dir, project_name + '.h5'), 
                                       monitor='val_dice_coef', mode= 'max' , save_best_only=True)

    log_dir = 'logs'
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    csv_logger = CSVLogger(os.path.join(log_dir,  project_name + '.txt'), separator=',', append=False)

    print('-'*30)
    print('Fitting model...')
    print('-'*30)

    steps_per_epoch = np.int(np.ceil((len(train_data_list)*(1+ AUG_RATE) )/batch_size))
    validation_steps = np.int(np.ceil(len(val_data_list)/batch_size))

    print("steps_per_epoch = ", steps_per_epoch)
    print("validation_steps = ", validation_steps)
    
    from tensorflow.keras import metrics
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5)
    ##### set learning rate ################
    lr=1e-4
    
    lr_finder = LRFinder(min_lr=5e-8, 
                    max_lr=8e-6, 
                    steps_per_epoch=steps_per_epoch, 
                    epochs=EPOCHS)
    
    scheduler = SGDRScheduler(min_lr=5e-8,
                        max_lr=8e-6,
                        steps_per_epoch=steps_per_epoch,
                        lr_decay=0.9,
                        cycle_length=5,
                        mult_factor=1.5)
    
    model.compile(optimizer=Adam(lr=lr), 
                  loss=loss_function, metrics=[metrics.binary_crossentropy, dice_coef])

    
    #model.fit(imgs_train, imgs_mask_train, batch_size=1, epochs=50, verbose=1, shuffle=True, validation_split=0.10, callbacks=[model_checkpoint, csv_logger])
    model.fit(train_dataset, validation_data = valid_dataset, steps_per_epoch = steps_per_epoch,
         validation_steps = validation_steps, epochs = EPOCHS, callbacks=[model_checkpoint,reduce_lr,lr_finder,scheduler, csv_logger,PlotLossesKerasTF()],
             verbose = 1)

    print('-'*30)
    print('Training finished')
    print('-'*30)

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]='0'
PROJECT_NAME = '3dDenseUnet'
train(False)
# Out:
# 3dDenseUnet
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# steps_per_epoch =  54
# validation_steps =  14
# Epoch 1/50
# 54/54 [==============================] - 323s 6s/step - loss: 0.8162 - binary_crossentropy: 0.3496 - dice_coef: 0.1842 - val_loss: 0.5002 - val_binary_crossentropy: 0.0467 - val_dice_coef: 0.5050
# Epoch 2/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.4536 - binary_crossentropy: 0.0452 - dice_coef: 0.5483 - val_loss: 0.4660 - val_binary_crossentropy: 0.0353 - val_dice_coef: 0.5405
# Epoch 3/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3972 - binary_crossentropy: 0.0342 - dice_coef: 0.6032 - val_loss: 0.3731 - val_binary_crossentropy: 0.0234 - val_dice_coef: 0.6311
# Epoch 4/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3577 - binary_crossentropy: 0.0311 - dice_coef: 0.6432 - val_loss: 0.3170 - val_binary_crossentropy: 0.0187 - val_dice_coef: 0.6868
# Epoch 5/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3239 - binary_crossentropy: 0.0268 - dice_coef: 0.6678 - val_loss: 0.3032 - val_binary_crossentropy: 0.0194 - val_dice_coef: 0.7008
# Epoch 6/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2644 - binary_crossentropy: 0.0219 - dice_coef: 0.7353 - val_loss: 0.2904 - val_binary_crossentropy: 0.0172 - val_dice_coef: 0.7144
# Epoch 7/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2966 - binary_crossentropy: 0.0251 - dice_coef: 0.7009 - val_loss: 0.3497 - val_binary_crossentropy: 0.0231 - val_dice_coef: 0.6551
# Epoch 8/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2613 - binary_crossentropy: 0.0215 - dice_coef: 0.7387 - val_loss: 0.2756 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7285
# Epoch 9/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2790 - binary_crossentropy: 0.0220 - dice_coef: 0.7216 - val_loss: 0.2803 - val_binary_crossentropy: 0.0177 - val_dice_coef: 0.7235
# Epoch 10/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2738 - binary_crossentropy: 0.0223 - dice_coef: 0.7278 - val_loss: 0.3684 - val_binary_crossentropy: 0.0256 - val_dice_coef: 0.6349
# Epoch 11/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2997 - binary_crossentropy: 0.0216 - dice_coef: 0.7017 - val_loss: 0.2676 - val_binary_crossentropy: 0.0177 - val_dice_coef: 0.7364
# Epoch 12/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2434 - binary_crossentropy: 0.0209 - dice_coef: 0.7567 - val_loss: 0.2623 - val_binary_crossentropy: 0.0164 - val_dice_coef: 0.7417
# Epoch 13/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2485 - binary_crossentropy: 0.0214 - dice_coef: 0.7519 - val_loss: 0.2703 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.7334
# Epoch 14/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2802 - binary_crossentropy: 0.0220 - dice_coef: 0.7109 - val_loss: 0.2872 - val_binary_crossentropy: 0.0195 - val_dice_coef: 0.7174
# Epoch 15/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2333 - binary_crossentropy: 0.0192 - dice_coef: 0.7572 - val_loss: 0.2548 - val_binary_crossentropy: 0.0176 - val_dice_coef: 0.7489
# Epoch 16/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2141 - binary_crossentropy: 0.0180 - dice_coef: 0.7870 - val_loss: 0.2558 - val_binary_crossentropy: 0.0169 - val_dice_coef: 0.7481
# Epoch 17/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2235 - binary_crossentropy: 0.0177 - dice_coef: 0.7739 - val_loss: 0.2819 - val_binary_crossentropy: 0.0217 - val_dice_coef: 0.7222
# Epoch 18/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2499 - binary_crossentropy: 0.0211 - dice_coef: 0.7409 - val_loss: 0.2608 - val_binary_crossentropy: 0.0169 - val_dice_coef: 0.7433
# Epoch 19/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2295 - binary_crossentropy: 0.0179 - dice_coef: 0.7711 - val_loss: 0.2482 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7553
# Epoch 20/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2213 - binary_crossentropy: 0.0196 - dice_coef: 0.7764 - val_loss: 0.2453 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7584
# Epoch 21/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2375 - binary_crossentropy: 0.0178 - dice_coef: 0.7616 - val_loss: 0.2440 - val_binary_crossentropy: 0.0166 - val_dice_coef: 0.7597
# Epoch 22/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2342 - binary_crossentropy: 0.0183 - dice_coef: 0.7667 - val_loss: 0.2499 - val_binary_crossentropy: 0.0176 - val_dice_coef: 0.7540
# Epoch 23/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1990 - binary_crossentropy: 0.0176 - dice_coef: 0.8003 - val_loss: 0.2835 - val_binary_crossentropy: 0.0211 - val_dice_coef: 0.7198
# Epoch 24/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2053 - binary_crossentropy: 0.0177 - dice_coef: 0.7951 - val_loss: 0.2415 - val_binary_crossentropy: 0.0171 - val_dice_coef: 0.7620
# Epoch 25/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.2169 - binary_crossentropy: 0.0184 - dice_coef: 0.7845 - val_loss: 0.2684 - val_binary_crossentropy: 0.0199 - val_dice_coef: 0.7352
# Epoch 26/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2065 - binary_crossentropy: 0.0179 - dice_coef: 0.7940 - val_loss: 0.2961 - val_binary_crossentropy: 0.0222 - val_dice_coef: 0.7078
# Epoch 27/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2138 - binary_crossentropy: 0.0180 - dice_coef: 0.7872 - val_loss: 0.2442 - val_binary_crossentropy: 0.0176 - val_dice_coef: 0.7595
# Epoch 28/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1932 - binary_crossentropy: 0.0172 - dice_coef: 0.8065 - val_loss: 0.2445 - val_binary_crossentropy: 0.0168 - val_dice_coef: 0.7587
# Epoch 29/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2077 - binary_crossentropy: 0.0179 - dice_coef: 0.7923 - val_loss: 0.2585 - val_binary_crossentropy: 0.0192 - val_dice_coef: 0.7449
# Epoch 30/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.2119 - binary_crossentropy: 0.0188 - dice_coef: 0.7890 - val_loss: 0.2453 - val_binary_crossentropy: 0.0188 - val_dice_coef: 0.7583
# Epoch 31/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1973 - binary_crossentropy: 0.0166 - dice_coef: 0.8032 - val_loss: 0.2537 - val_binary_crossentropy: 0.0184 - val_dice_coef: 0.7497
# Epoch 32/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1824 - binary_crossentropy: 0.0172 - dice_coef: 0.8177 - val_loss: 0.2679 - val_binary_crossentropy: 0.0205 - val_dice_coef: 0.7360
# Epoch 33/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1922 - binary_crossentropy: 0.0164 - dice_coef: 0.8086 - val_loss: 0.2644 - val_binary_crossentropy: 0.0194 - val_dice_coef: 0.7390
# Epoch 34/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.2008 - binary_crossentropy: 0.0151 - dice_coef: 0.8010 - val_loss: 0.2490 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.7548
# Epoch 35/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1841 - binary_crossentropy: 0.0151 - dice_coef: 0.8170 - val_loss: 0.2532 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7499
# Epoch 36/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1824 - binary_crossentropy: 0.0157 - dice_coef: 0.8184 - val_loss: 0.2428 - val_binary_crossentropy: 0.0187 - val_dice_coef: 0.7610
# Epoch 37/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1843 - binary_crossentropy: 0.0150 - dice_coef: 0.8063 - val_loss: 0.2373 - val_binary_crossentropy: 0.0170 - val_dice_coef: 0.7665
# Epoch 38/50
# 54/54 [==============================] - 283s 5s/step - loss: 0.1643 - binary_crossentropy: 0.0137 - dice_coef: 0.8303 - val_loss: 0.2476 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.7560
# Epoch 39/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1660 - binary_crossentropy: 0.0148 - dice_coef: 0.8348 - val_loss: 0.2756 - val_binary_crossentropy: 0.0209 - val_dice_coef: 0.7280
# Epoch 40/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1605 - binary_crossentropy: 0.0140 - dice_coef: 0.8382 - val_loss: 0.2442 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7592
# Epoch 41/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1872 - binary_crossentropy: 0.0159 - dice_coef: 0.8073 - val_loss: 0.2780 - val_binary_crossentropy: 0.0219 - val_dice_coef: 0.7260
# Epoch 42/50
# 54/54 [==============================] - 283s 5s/step - loss: 0.1860 - binary_crossentropy: 0.0165 - dice_coef: 0.8146 - val_loss: 0.2997 - val_binary_crossentropy: 0.0238 - val_dice_coef: 0.7036
# Epoch 43/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1664 - binary_crossentropy: 0.0143 - dice_coef: 0.8328 - val_loss: 0.2610 - val_binary_crossentropy: 0.0196 - val_dice_coef: 0.7427
# Epoch 44/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1599 - binary_crossentropy: 0.0137 - dice_coef: 0.8401 - val_loss: 0.2435 - val_binary_crossentropy: 0.0191 - val_dice_coef: 0.7603
# Epoch 45/50
# 54/54 [==============================] - 283s 5s/step - loss: 0.1448 - binary_crossentropy: 0.0129 - dice_coef: 0.8551 - val_loss: 0.2730 - val_binary_crossentropy: 0.0216 - val_dice_coef: 0.7306
# Epoch 46/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1596 - binary_crossentropy: 0.0129 - dice_coef: 0.8416 - val_loss: 0.2440 - val_binary_crossentropy: 0.0192 - val_dice_coef: 0.7589
# Epoch 47/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1445 - binary_crossentropy: 0.0126 - dice_coef: 0.8554 - val_loss: 0.2468 - val_binary_crossentropy: 0.0195 - val_dice_coef: 0.7575
# Epoch 48/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1394 - binary_crossentropy: 0.0121 - dice_coef: 0.8612 - val_loss: 0.2423 - val_binary_crossentropy: 0.0197 - val_dice_coef: 0.7614
# Epoch 49/50
# 54/54 [==============================] - 283s 5s/step - loss: 0.1514 - binary_crossentropy: 0.0122 - dice_coef: 0.8498 - val_loss: 0.2569 - val_binary_crossentropy: 0.0204 - val_dice_coef: 0.7468
# Epoch 50/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.1340 - binary_crossentropy: 0.0118 - dice_coef: 0.8658 - val_loss: 0.2574 - val_binary_crossentropy: 0.0195 - val_dice_coef: 0.7466
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_att_c1'
train(True, 1 )
# Out:
# 3dDenseUnet_att_c1
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# steps_per_epoch =  54
# validation_steps =  14
# Epoch 1/50
# 54/54 [==============================] - 290s 5s/step - loss: 0.7850 - binary_crossentropy: 0.2819 - dice_coef: 0.2149 - val_loss: 0.4952 - val_binary_crossentropy: 0.0314 - val_dice_coef: 0.5105
# Epoch 2/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.4357 - binary_crossentropy: 0.0322 - dice_coef: 0.5677 - val_loss: 0.4618 - val_binary_crossentropy: 0.0279 - val_dice_coef: 0.5449
# Epoch 3/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.3930 - binary_crossentropy: 0.0314 - dice_coef: 0.6052 - val_loss: 0.4339 - val_binary_crossentropy: 0.0299 - val_dice_coef: 0.5725
# Epoch 4/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.3924 - binary_crossentropy: 0.0304 - dice_coef: 0.6091 - val_loss: 0.4064 - val_binary_crossentropy: 0.0280 - val_dice_coef: 0.5998
# Epoch 5/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3456 - binary_crossentropy: 0.0290 - dice_coef: 0.6494 - val_loss: 0.3652 - val_binary_crossentropy: 0.0179 - val_dice_coef: 0.6363
# Epoch 6/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3208 - binary_crossentropy: 0.0205 - dice_coef: 0.6796 - val_loss: 0.3519 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.6510
# Epoch 7/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.3026 - binary_crossentropy: 0.0201 - dice_coef: 0.6997 - val_loss: 0.3889 - val_binary_crossentropy: 0.0189 - val_dice_coef: 0.6151
# Epoch 8/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2736 - binary_crossentropy: 0.0188 - dice_coef: 0.7180 - val_loss: 0.2916 - val_binary_crossentropy: 0.0165 - val_dice_coef: 0.7132
# Epoch 9/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2512 - binary_crossentropy: 0.0188 - dice_coef: 0.7464 - val_loss: 0.3142 - val_binary_crossentropy: 0.0154 - val_dice_coef: 0.6884
# Epoch 10/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2702 - binary_crossentropy: 0.0183 - dice_coef: 0.7274 - val_loss: 0.2769 - val_binary_crossentropy: 0.0165 - val_dice_coef: 0.7277
# Epoch 11/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2617 - binary_crossentropy: 0.0174 - dice_coef: 0.7401 - val_loss: 0.2604 - val_binary_crossentropy: 0.0153 - val_dice_coef: 0.7441
# Epoch 12/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2202 - binary_crossentropy: 0.0161 - dice_coef: 0.7801 - val_loss: 0.2880 - val_binary_crossentropy: 0.0163 - val_dice_coef: 0.7158
# Epoch 13/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2390 - binary_crossentropy: 0.0162 - dice_coef: 0.7516 - val_loss: 0.2669 - val_binary_crossentropy: 0.0166 - val_dice_coef: 0.7375
# Epoch 14/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2298 - binary_crossentropy: 0.0164 - dice_coef: 0.7718 - val_loss: 0.2613 - val_binary_crossentropy: 0.0157 - val_dice_coef: 0.7428
# Epoch 15/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2216 - binary_crossentropy: 0.0156 - dice_coef: 0.7781 - val_loss: 0.2516 - val_binary_crossentropy: 0.0147 - val_dice_coef: 0.7518
# Epoch 16/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2371 - binary_crossentropy: 0.0167 - dice_coef: 0.7636 - val_loss: 0.2610 - val_binary_crossentropy: 0.0158 - val_dice_coef: 0.7431
# Epoch 17/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2362 - binary_crossentropy: 0.0172 - dice_coef: 0.7649 - val_loss: 0.2499 - val_binary_crossentropy: 0.0149 - val_dice_coef: 0.7542
# Epoch 18/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2200 - binary_crossentropy: 0.0152 - dice_coef: 0.7818 - val_loss: 0.2571 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7472
# Epoch 19/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2154 - binary_crossentropy: 0.0152 - dice_coef: 0.7859 - val_loss: 0.2422 - val_binary_crossentropy: 0.0150 - val_dice_coef: 0.7618
# Epoch 20/50
# 54/54 [==============================] - 284s 5s/step - loss: 0.2134 - binary_crossentropy: 0.0155 - dice_coef: 0.7787 - val_loss: 0.2457 - val_binary_crossentropy: 0.0150 - val_dice_coef: 0.7583
# Epoch 21/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2133 - binary_crossentropy: 0.0162 - dice_coef: 0.7879 - val_loss: 0.2413 - val_binary_crossentropy: 0.0151 - val_dice_coef: 0.7629
# Epoch 22/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2216 - binary_crossentropy: 0.0154 - dice_coef: 0.7791 - val_loss: 0.2542 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7484
# Epoch 23/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2109 - binary_crossentropy: 0.0153 - dice_coef: 0.7863 - val_loss: 0.2524 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7495
# Epoch 24/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2080 - binary_crossentropy: 0.0146 - dice_coef: 0.7924 - val_loss: 0.2449 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7582
# Epoch 25/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1851 - binary_crossentropy: 0.0148 - dice_coef: 0.8154 - val_loss: 0.2498 - val_binary_crossentropy: 0.0169 - val_dice_coef: 0.7535
# Epoch 26/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1928 - binary_crossentropy: 0.0153 - dice_coef: 0.8082 - val_loss: 0.2544 - val_binary_crossentropy: 0.0164 - val_dice_coef: 0.7481
# Epoch 27/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1878 - binary_crossentropy: 0.0147 - dice_coef: 0.8117 - val_loss: 0.2491 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7544
# Epoch 28/50
# 54/54 [==============================] - 283s 5s/step - loss: 0.1853 - binary_crossentropy: 0.0152 - dice_coef: 0.8047 - val_loss: 0.2420 - val_binary_crossentropy: 0.0172 - val_dice_coef: 0.7614
# Epoch 29/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1749 - binary_crossentropy: 0.0141 - dice_coef: 0.8256 - val_loss: 0.2453 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7581
# Epoch 30/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1867 - binary_crossentropy: 0.0157 - dice_coef: 0.8132 - val_loss: 0.2914 - val_binary_crossentropy: 0.0225 - val_dice_coef: 0.7120
# Epoch 31/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.2229 - binary_crossentropy: 0.0180 - dice_coef: 0.7791 - val_loss: 0.2457 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7579
# Epoch 32/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1973 - binary_crossentropy: 0.0156 - dice_coef: 0.8027 - val_loss: 0.2347 - val_binary_crossentropy: 0.0161 - val_dice_coef: 0.7681
# Epoch 33/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1805 - binary_crossentropy: 0.0146 - dice_coef: 0.8175 - val_loss: 0.2537 - val_binary_crossentropy: 0.0185 - val_dice_coef: 0.7498
# Epoch 34/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1665 - binary_crossentropy: 0.0142 - dice_coef: 0.8341 - val_loss: 0.2502 - val_binary_crossentropy: 0.0188 - val_dice_coef: 0.7535
# Epoch 35/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1655 - binary_crossentropy: 0.0138 - dice_coef: 0.8292 - val_loss: 0.2575 - val_binary_crossentropy: 0.0191 - val_dice_coef: 0.7465
# Epoch 36/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1683 - binary_crossentropy: 0.0146 - dice_coef: 0.8327 - val_loss: 0.2494 - val_binary_crossentropy: 0.0188 - val_dice_coef: 0.7532
# Epoch 37/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1514 - binary_crossentropy: 0.0134 - dice_coef: 0.8487 - val_loss: 0.2319 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7719
# Epoch 38/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1649 - binary_crossentropy: 0.0135 - dice_coef: 0.8359 - val_loss: 0.2570 - val_binary_crossentropy: 0.0204 - val_dice_coef: 0.7457
# Epoch 39/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1677 - binary_crossentropy: 0.0151 - dice_coef: 0.8296 - val_loss: 0.2376 - val_binary_crossentropy: 0.0175 - val_dice_coef: 0.7662
# Epoch 40/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1533 - binary_crossentropy: 0.0131 - dice_coef: 0.8475 - val_loss: 0.2291 - val_binary_crossentropy: 0.0177 - val_dice_coef: 0.7746
# Epoch 41/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1475 - binary_crossentropy: 0.0136 - dice_coef: 0.8520 - val_loss: 0.2421 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7615
# Epoch 42/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1566 - binary_crossentropy: 0.0139 - dice_coef: 0.8419 - val_loss: 0.2211 - val_binary_crossentropy: 0.0172 - val_dice_coef: 0.7825
# Epoch 43/50
# 54/54 [==============================] - 291s 5s/step - loss: 0.1544 - binary_crossentropy: 0.0125 - dice_coef: 0.8469 - val_loss: 0.2373 - val_binary_crossentropy: 0.0176 - val_dice_coef: 0.7667
# Epoch 44/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1443 - binary_crossentropy: 0.0115 - dice_coef: 0.8562 - val_loss: 0.2450 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7588
# Epoch 45/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1434 - binary_crossentropy: 0.0120 - dice_coef: 0.8567 - val_loss: 0.2278 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.7760
# Epoch 46/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1302 - binary_crossentropy: 0.0112 - dice_coef: 0.8699 - val_loss: 0.2388 - val_binary_crossentropy: 0.0179 - val_dice_coef: 0.7654
# Epoch 47/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1169 - binary_crossentropy: 0.0105 - dice_coef: 0.8823 - val_loss: 0.2399 - val_binary_crossentropy: 0.0175 - val_dice_coef: 0.7639
# Epoch 48/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1301 - binary_crossentropy: 0.0113 - dice_coef: 0.8690 - val_loss: 0.2314 - val_binary_crossentropy: 0.0172 - val_dice_coef: 0.7723
# Epoch 49/50
# 54/54 [==============================] - 290s 5s/step - loss: 0.1304 - binary_crossentropy: 0.0107 - dice_coef: 0.8705 - val_loss: 0.2361 - val_binary_crossentropy: 0.0177 - val_dice_coef: 0.7677
# Epoch 50/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1255 - binary_crossentropy: 0.0106 - dice_coef: 0.8750 - val_loss: 0.2502 - val_binary_crossentropy: 0.0203 - val_dice_coef: 0.7531
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'
PROJECT_NAME = '3dDenseUnet_att_c4'
train(True, 4 )
# Out:
# 3dDenseUnet_att_c4
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# steps_per_epoch =  54
# validation_steps =  14
# Epoch 1/50
# 54/54 [==============================] - 292s 5s/step - loss: 0.8801 - binary_crossentropy: 0.4131 - dice_coef: 0.1197 - val_loss: 0.6874 - val_binary_crossentropy: 0.0893 - val_dice_coef: 0.3159
# Epoch 2/50
# 54/54 [==============================] - 290s 5s/step - loss: 0.4944 - binary_crossentropy: 0.0431 - dice_coef: 0.5013 - val_loss: 0.4698 - val_binary_crossentropy: 0.0294 - val_dice_coef: 0.5373
# Epoch 3/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.4159 - binary_crossentropy: 0.0313 - dice_coef: 0.5833 - val_loss: 0.4516 - val_binary_crossentropy: 0.0296 - val_dice_coef: 0.5558
# Epoch 4/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.4085 - binary_crossentropy: 0.0312 - dice_coef: 0.5887 - val_loss: 0.4063 - val_binary_crossentropy: 0.0278 - val_dice_coef: 0.5993
# Epoch 5/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.3476 - binary_crossentropy: 0.0306 - dice_coef: 0.6443 - val_loss: 0.4450 - val_binary_crossentropy: 0.0329 - val_dice_coef: 0.5604
# Epoch 6/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3362 - binary_crossentropy: 0.0270 - dice_coef: 0.6611 - val_loss: 0.4125 - val_binary_crossentropy: 0.0260 - val_dice_coef: 0.5921
# Epoch 7/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.3090 - binary_crossentropy: 0.0226 - dice_coef: 0.6927 - val_loss: 0.3365 - val_binary_crossentropy: 0.0220 - val_dice_coef: 0.6677
# Epoch 8/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2689 - binary_crossentropy: 0.0214 - dice_coef: 0.7287 - val_loss: 0.3026 - val_binary_crossentropy: 0.0191 - val_dice_coef: 0.7018
# Epoch 9/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2807 - binary_crossentropy: 0.0211 - dice_coef: 0.7214 - val_loss: 0.3315 - val_binary_crossentropy: 0.0211 - val_dice_coef: 0.6726
# Epoch 10/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.2792 - binary_crossentropy: 0.0181 - dice_coef: 0.7201 - val_loss: 0.2663 - val_binary_crossentropy: 0.0153 - val_dice_coef: 0.7382
# Epoch 11/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2506 - binary_crossentropy: 0.0198 - dice_coef: 0.7501 - val_loss: 0.3009 - val_binary_crossentropy: 0.0154 - val_dice_coef: 0.7028
# Epoch 12/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.2479 - binary_crossentropy: 0.0180 - dice_coef: 0.7519 - val_loss: 0.2619 - val_binary_crossentropy: 0.0157 - val_dice_coef: 0.7424
# Epoch 13/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2458 - binary_crossentropy: 0.0204 - dice_coef: 0.7521 - val_loss: 0.2662 - val_binary_crossentropy: 0.0159 - val_dice_coef: 0.7383
# Epoch 14/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2404 - binary_crossentropy: 0.0162 - dice_coef: 0.7600 - val_loss: 0.2794 - val_binary_crossentropy: 0.0179 - val_dice_coef: 0.7249
# Epoch 15/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.2263 - binary_crossentropy: 0.0161 - dice_coef: 0.7743 - val_loss: 0.2522 - val_binary_crossentropy: 0.0156 - val_dice_coef: 0.7519
# Epoch 16/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2198 - binary_crossentropy: 0.0165 - dice_coef: 0.7786 - val_loss: 0.2992 - val_binary_crossentropy: 0.0190 - val_dice_coef: 0.7055
# Epoch 17/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2029 - binary_crossentropy: 0.0155 - dice_coef: 0.7976 - val_loss: 0.2892 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7143
# Epoch 18/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2121 - binary_crossentropy: 0.0158 - dice_coef: 0.7782 - val_loss: 0.2647 - val_binary_crossentropy: 0.0161 - val_dice_coef: 0.7395
# Epoch 19/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2240 - binary_crossentropy: 0.0162 - dice_coef: 0.7776 - val_loss: 0.2580 - val_binary_crossentropy: 0.0166 - val_dice_coef: 0.7461
# Epoch 20/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.2234 - binary_crossentropy: 0.0171 - dice_coef: 0.7670 - val_loss: 0.2418 - val_binary_crossentropy: 0.0153 - val_dice_coef: 0.7619
# Epoch 21/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1937 - binary_crossentropy: 0.0158 - dice_coef: 0.7987 - val_loss: 0.2586 - val_binary_crossentropy: 0.0168 - val_dice_coef: 0.7453
# Epoch 22/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2220 - binary_crossentropy: 0.0184 - dice_coef: 0.7797 - val_loss: 0.2590 - val_binary_crossentropy: 0.0172 - val_dice_coef: 0.7454
# Epoch 23/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.1995 - binary_crossentropy: 0.0156 - dice_coef: 0.8015 - val_loss: 0.2445 - val_binary_crossentropy: 0.0160 - val_dice_coef: 0.7594
# Epoch 24/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2033 - binary_crossentropy: 0.0155 - dice_coef: 0.7966 - val_loss: 0.2636 - val_binary_crossentropy: 0.0186 - val_dice_coef: 0.7396
# Epoch 25/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1882 - binary_crossentropy: 0.0154 - dice_coef: 0.8067 - val_loss: 0.2356 - val_binary_crossentropy: 0.0158 - val_dice_coef: 0.7680
# Epoch 26/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.2070 - binary_crossentropy: 0.0160 - dice_coef: 0.7942 - val_loss: 0.2649 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7397
# Epoch 27/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.2018 - binary_crossentropy: 0.0163 - dice_coef: 0.7970 - val_loss: 0.2400 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7639
# Epoch 28/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1989 - binary_crossentropy: 0.0147 - dice_coef: 0.8014 - val_loss: 0.2493 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.7542
# Epoch 29/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1764 - binary_crossentropy: 0.0147 - dice_coef: 0.8234 - val_loss: 0.2715 - val_binary_crossentropy: 0.0202 - val_dice_coef: 0.7307
# Epoch 30/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1904 - binary_crossentropy: 0.0166 - dice_coef: 0.8086 - val_loss: 0.2589 - val_binary_crossentropy: 0.0185 - val_dice_coef: 0.7450
# Epoch 31/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1760 - binary_crossentropy: 0.0148 - dice_coef: 0.8242 - val_loss: 0.2471 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.7568
# Epoch 32/50
# 54/54 [==============================] - 285s 5s/step - loss: 0.1670 - binary_crossentropy: 0.0146 - dice_coef: 0.8328 - val_loss: 0.2373 - val_binary_crossentropy: 0.0174 - val_dice_coef: 0.7664
# Epoch 33/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1783 - binary_crossentropy: 0.0144 - dice_coef: 0.8223 - val_loss: 0.2402 - val_binary_crossentropy: 0.0171 - val_dice_coef: 0.7633
# Epoch 34/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1732 - binary_crossentropy: 0.0144 - dice_coef: 0.8186 - val_loss: 0.2426 - val_binary_crossentropy: 0.0185 - val_dice_coef: 0.7610
# Epoch 35/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1945 - binary_crossentropy: 0.0158 - dice_coef: 0.8021 - val_loss: 0.2458 - val_binary_crossentropy: 0.0177 - val_dice_coef: 0.7583
# Epoch 36/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1711 - binary_crossentropy: 0.0138 - dice_coef: 0.8187 - val_loss: 0.2420 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.7617
# Epoch 37/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1660 - binary_crossentropy: 0.0139 - dice_coef: 0.8321 - val_loss: 0.2524 - val_binary_crossentropy: 0.0187 - val_dice_coef: 0.7510
# Epoch 38/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1586 - binary_crossentropy: 0.0133 - dice_coef: 0.8413 - val_loss: 0.2439 - val_binary_crossentropy: 0.0176 - val_dice_coef: 0.7599
# Epoch 39/50
# 54/54 [==============================] - 286s 5s/step - loss: 0.1526 - binary_crossentropy: 0.0125 - dice_coef: 0.8459 - val_loss: 0.2575 - val_binary_crossentropy: 0.0194 - val_dice_coef: 0.7457
# Epoch 40/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1714 - binary_crossentropy: 0.0131 - dice_coef: 0.8290 - val_loss: 0.2487 - val_binary_crossentropy: 0.0189 - val_dice_coef: 0.7552
# Epoch 41/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1577 - binary_crossentropy: 0.0136 - dice_coef: 0.8413 - val_loss: 0.2392 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.7645
# Epoch 42/50
# 54/54 [==============================] - 290s 5s/step - loss: 0.1436 - binary_crossentropy: 0.0119 - dice_coef: 0.8491 - val_loss: 0.2434 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7607
# Epoch 43/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1577 - binary_crossentropy: 0.0129 - dice_coef: 0.8430 - val_loss: 0.2465 - val_binary_crossentropy: 0.0181 - val_dice_coef: 0.7575
# Epoch 44/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1384 - binary_crossentropy: 0.0115 - dice_coef: 0.8622 - val_loss: 0.2506 - val_binary_crossentropy: 0.0193 - val_dice_coef: 0.7532
# Epoch 45/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.1349 - binary_crossentropy: 0.0114 - dice_coef: 0.8652 - val_loss: 0.2770 - val_binary_crossentropy: 0.0212 - val_dice_coef: 0.7269
# Epoch 46/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1506 - binary_crossentropy: 0.0123 - dice_coef: 0.8505 - val_loss: 0.2441 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.7594
# Epoch 47/50
# 54/54 [==============================] - 289s 5s/step - loss: 0.1346 - binary_crossentropy: 0.0115 - dice_coef: 0.8656 - val_loss: 0.2390 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7649
# Epoch 48/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1448 - binary_crossentropy: 0.0116 - dice_coef: 0.8560 - val_loss: 0.2363 - val_binary_crossentropy: 0.0182 - val_dice_coef: 0.7672
# Epoch 49/50
# 54/54 [==============================] - 288s 5s/step - loss: 0.1283 - binary_crossentropy: 0.0107 - dice_coef: 0.8721 - val_loss: 0.2522 - val_binary_crossentropy: 0.0195 - val_dice_coef: 0.7509
# Epoch 50/50
# 54/54 [==============================] - 287s 5s/step - loss: 0.1127 - binary_crossentropy: 0.0103 - dice_coef: 0.8874 - val_loss: 0.2514 - val_binary_crossentropy: 0.0196 - val_dice_coef: 0.7524
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_att_hyper_c1'
train(att_input= True, inter_channel = 1, hyper= True)
# Out:
# 3dDenseUnet_att_hyper_c1
# ------------------------------
# Creating and compiling model...
# ------------------------------
# ------------------------------
# Fitting model...
# ------------------------------
# steps_per_epoch =  54
# validation_steps =  14
# Epoch 1/50
# 54/54 [==============================] - 281s 5s/step - loss: 0.7869 - binary_crossentropy: 0.1692 - dice_coef: 0.2250 - val_loss: 0.5204 - val_binary_crossentropy: 0.0218 - val_dice_coef: 0.4893
# Epoch 2/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.4578 - binary_crossentropy: 0.0275 - dice_coef: 0.5483 - val_loss: 0.5274 - val_binary_crossentropy: 0.0278 - val_dice_coef: 0.4866
# Epoch 3/50
# 54/54 [==============================] - 280s 5s/step - loss: 0.3954 - binary_crossentropy: 0.0227 - dice_coef: 0.6019 - val_loss: 0.4431 - val_binary_crossentropy: 0.0242 - val_dice_coef: 0.5658
# Epoch 4/50
# 54/54 [==============================] - 280s 5s/step - loss: 0.3448 - binary_crossentropy: 0.0206 - dice_coef: 0.6590 - val_loss: 0.4207 - val_binary_crossentropy: 0.0201 - val_dice_coef: 0.5907
# Epoch 5/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.3341 - binary_crossentropy: 0.0207 - dice_coef: 0.6714 - val_loss: 0.3812 - val_binary_crossentropy: 0.0180 - val_dice_coef: 0.6287
# Epoch 6/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.3107 - binary_crossentropy: 0.0174 - dice_coef: 0.6856 - val_loss: 0.3181 - val_binary_crossentropy: 0.0131 - val_dice_coef: 0.6894
# Epoch 7/50
# 54/54 [==============================] - 280s 5s/step - loss: 0.2954 - binary_crossentropy: 0.0176 - dice_coef: 0.7084 - val_loss: 0.2895 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7169
# Epoch 8/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2757 - binary_crossentropy: 0.0157 - dice_coef: 0.7293 - val_loss: 0.2981 - val_binary_crossentropy: 0.0162 - val_dice_coef: 0.7084
# Epoch 9/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2697 - binary_crossentropy: 0.0174 - dice_coef: 0.7247 - val_loss: 0.3069 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.6998
# Epoch 10/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2763 - binary_crossentropy: 0.0161 - dice_coef: 0.7256 - val_loss: 0.2790 - val_binary_crossentropy: 0.0156 - val_dice_coef: 0.7275
# Epoch 11/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2576 - binary_crossentropy: 0.0161 - dice_coef: 0.7474 - val_loss: 0.2632 - val_binary_crossentropy: 0.0147 - val_dice_coef: 0.7431
# Epoch 12/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2832 - binary_crossentropy: 0.0159 - dice_coef: 0.7183 - val_loss: 0.2829 - val_binary_crossentropy: 0.0165 - val_dice_coef: 0.7239
# Epoch 13/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2568 - binary_crossentropy: 0.0155 - dice_coef: 0.7413 - val_loss: 0.3079 - val_binary_crossentropy: 0.0134 - val_dice_coef: 0.6989
# Epoch 14/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2582 - binary_crossentropy: 0.0148 - dice_coef: 0.7463 - val_loss: 0.2687 - val_binary_crossentropy: 0.0147 - val_dice_coef: 0.7380
# Epoch 15/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2372 - binary_crossentropy: 0.0151 - dice_coef: 0.7631 - val_loss: 0.2659 - val_binary_crossentropy: 0.0142 - val_dice_coef: 0.7407
# Epoch 16/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2285 - binary_crossentropy: 0.0139 - dice_coef: 0.7741 - val_loss: 0.2702 - val_binary_crossentropy: 0.0144 - val_dice_coef: 0.7368
# Epoch 17/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2069 - binary_crossentropy: 0.0130 - dice_coef: 0.7961 - val_loss: 0.2789 - val_binary_crossentropy: 0.0168 - val_dice_coef: 0.7272
# Epoch 18/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2139 - binary_crossentropy: 0.0137 - dice_coef: 0.7909 - val_loss: 0.2541 - val_binary_crossentropy: 0.0145 - val_dice_coef: 0.7522
# Epoch 19/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2374 - binary_crossentropy: 0.0142 - dice_coef: 0.7663 - val_loss: 0.2677 - val_binary_crossentropy: 0.0128 - val_dice_coef: 0.7390
# Epoch 20/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.2250 - binary_crossentropy: 0.0134 - dice_coef: 0.7788 - val_loss: 0.2633 - val_binary_crossentropy: 0.0127 - val_dice_coef: 0.7436
# Epoch 21/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.2139 - binary_crossentropy: 0.0129 - dice_coef: 0.7905 - val_loss: 0.2747 - val_binary_crossentropy: 0.0127 - val_dice_coef: 0.7321
# Epoch 22/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2096 - binary_crossentropy: 0.0133 - dice_coef: 0.7925 - val_loss: 0.2672 - val_binary_crossentropy: 0.0158 - val_dice_coef: 0.7387
# Epoch 23/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2043 - binary_crossentropy: 0.0127 - dice_coef: 0.7995 - val_loss: 0.2493 - val_binary_crossentropy: 0.0140 - val_dice_coef: 0.7575
# Epoch 24/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1968 - binary_crossentropy: 0.0130 - dice_coef: 0.8059 - val_loss: 0.2612 - val_binary_crossentropy: 0.0135 - val_dice_coef: 0.7459
# Epoch 25/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1838 - binary_crossentropy: 0.0121 - dice_coef: 0.8190 - val_loss: 0.2575 - val_binary_crossentropy: 0.0141 - val_dice_coef: 0.7494
# Epoch 26/50
# 54/54 [==============================] - 279s 5s/step - loss: 0.2163 - binary_crossentropy: 0.0139 - dice_coef: 0.7811 - val_loss: 0.3142 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.6954
# Epoch 27/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.3211 - binary_crossentropy: 0.0235 - dice_coef: 0.6758 - val_loss: 0.2670 - val_binary_crossentropy: 0.0126 - val_dice_coef: 0.7401
# Epoch 28/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.2630 - binary_crossentropy: 0.0162 - dice_coef: 0.7389 - val_loss: 0.2521 - val_binary_crossentropy: 0.0143 - val_dice_coef: 0.7546
# Epoch 29/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.2213 - binary_crossentropy: 0.0135 - dice_coef: 0.7828 - val_loss: 0.2602 - val_binary_crossentropy: 0.0160 - val_dice_coef: 0.7463
# Epoch 30/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.2190 - binary_crossentropy: 0.0133 - dice_coef: 0.7807 - val_loss: 0.2513 - val_binary_crossentropy: 0.0138 - val_dice_coef: 0.7553
# Epoch 31/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.2179 - binary_crossentropy: 0.0144 - dice_coef: 0.7797 - val_loss: 0.2581 - val_binary_crossentropy: 0.0141 - val_dice_coef: 0.7486
# Epoch 32/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.2297 - binary_crossentropy: 0.0138 - dice_coef: 0.7637 - val_loss: 0.2661 - val_binary_crossentropy: 0.0136 - val_dice_coef: 0.7411
# Epoch 33/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.2102 - binary_crossentropy: 0.0128 - dice_coef: 0.7936 - val_loss: 0.2525 - val_binary_crossentropy: 0.0155 - val_dice_coef: 0.7542
# Epoch 34/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.2178 - binary_crossentropy: 0.0132 - dice_coef: 0.7815 - val_loss: 0.2519 - val_binary_crossentropy: 0.0151 - val_dice_coef: 0.7553
# Epoch 35/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.2098 - binary_crossentropy: 0.0132 - dice_coef: 0.7944 - val_loss: 0.2505 - val_binary_crossentropy: 0.0144 - val_dice_coef: 0.7561
# Epoch 36/50
# 54/54 [==============================] - 275s 5s/step - loss: 0.1971 - binary_crossentropy: 0.0121 - dice_coef: 0.8064 - val_loss: 0.2641 - val_binary_crossentropy: 0.0137 - val_dice_coef: 0.7437
# Epoch 37/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.1832 - binary_crossentropy: 0.0119 - dice_coef: 0.8207 - val_loss: 0.2580 - val_binary_crossentropy: 0.0161 - val_dice_coef: 0.7491
# Epoch 38/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1844 - binary_crossentropy: 0.0117 - dice_coef: 0.8186 - val_loss: 0.2583 - val_binary_crossentropy: 0.0161 - val_dice_coef: 0.7484
# Epoch 39/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.1786 - binary_crossentropy: 0.0121 - dice_coef: 0.8141 - val_loss: 0.2645 - val_binary_crossentropy: 0.0162 - val_dice_coef: 0.7430
# Epoch 40/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1944 - binary_crossentropy: 0.0118 - dice_coef: 0.8088 - val_loss: 0.2581 - val_binary_crossentropy: 0.0169 - val_dice_coef: 0.7487
# Epoch 41/50
# 54/54 [==============================] - 278s 5s/step - loss: 0.1785 - binary_crossentropy: 0.0117 - dice_coef: 0.8253 - val_loss: 0.2475 - val_binary_crossentropy: 0.0150 - val_dice_coef: 0.7599
# Epoch 42/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.1674 - binary_crossentropy: 0.0111 - dice_coef: 0.8249 - val_loss: 0.2524 - val_binary_crossentropy: 0.0145 - val_dice_coef: 0.7542
# Epoch 43/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1662 - binary_crossentropy: 0.0110 - dice_coef: 0.8371 - val_loss: 0.2821 - val_binary_crossentropy: 0.0188 - val_dice_coef: 0.7245
# Epoch 44/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.1737 - binary_crossentropy: 0.0113 - dice_coef: 0.8300 - val_loss: 0.2541 - val_binary_crossentropy: 0.0167 - val_dice_coef: 0.7526
# Epoch 45/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1689 - binary_crossentropy: 0.0112 - dice_coef: 0.8346 - val_loss: 0.2623 - val_binary_crossentropy: 0.0178 - val_dice_coef: 0.7447
# Epoch 46/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1721 - binary_crossentropy: 0.0110 - dice_coef: 0.8279 - val_loss: 0.2559 - val_binary_crossentropy: 0.0166 - val_dice_coef: 0.7511
# Epoch 47/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1724 - binary_crossentropy: 0.0112 - dice_coef: 0.8304 - val_loss: 0.2634 - val_binary_crossentropy: 0.0173 - val_dice_coef: 0.7434
# Epoch 48/50
# 54/54 [==============================] - 276s 5s/step - loss: 0.1677 - binary_crossentropy: 0.0106 - dice_coef: 0.8357 - val_loss: 0.2529 - val_binary_crossentropy: 0.0165 - val_dice_coef: 0.7539
# Epoch 49/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1448 - binary_crossentropy: 0.0098 - dice_coef: 0.8579 - val_loss: 0.2542 - val_binary_crossentropy: 0.0163 - val_dice_coef: 0.7533
# Epoch 50/50
# 54/54 [==============================] - 277s 5s/step - loss: 0.1387 - binary_crossentropy: 0.0097 - dice_coef: 0.8641 - val_loss: 0.2459 - val_binary_crossentropy: 0.0154 - val_dice_coef: 0.7613
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_att_hyper_c1_dropout'
train(att_input= True, inter_channel = 1)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.011, max:    0.351, cur:    0.011)
# 	validation       	 (min:    0.015, max:    0.057, cur:    0.020)
# dice_coef
# 	training         	 (min:    0.170, max:    0.873, cur:    0.873)
# 	validation       	 (min:    0.448, max:    0.763, cur:    0.745)
# Loss
# 	training         	 (min:    0.127, max:    0.830, cur:    0.127)
# 	validation       	 (min:    0.241, max:    0.557, cur:    0.259)
# 54/54 [==============================] - 277s 5s/step - loss: 0.1275 - binary_crossentropy: 0.0113 - dice_coef: 0.8728 - val_loss: 0.2585 - val_binary_crossentropy: 0.0202 - val_dice_coef: 0.7450
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'
PROJECT_NAME = '3dDenseUnet_dropout'
train(att_input= False)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.011, max:    0.351, cur:    0.013)
# 	validation       	 (min:    0.015, max:    0.057, cur:    0.020)
# dice_coef
# 	training         	 (min:    0.170, max:    0.873, cur:    0.855)
# 	validation       	 (min:    0.448, max:    0.767, cur:    0.757)
# Loss
# 	training         	 (min:    0.127, max:    0.830, cur:    0.145)
# 	validation       	 (min:    0.236, max:    0.557, cur:    0.246)
# 54/54 [==============================] - 276s 5s/step - loss: 0.1447 - binary_crossentropy: 0.0132 - dice_coef: 0.8548 - val_loss: 0.2464 - val_binary_crossentropy: 0.0199 - val_dice_coef: 0.7573
# ------------------------------
# Training finished
# ------------------------------

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'
PROJECT_NAME = '3dDenseUnet_dropout_augmentation'
train(att_input= False)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.017, max:    0.701, cur:    0.018)
# 	validation       	 (min:    0.014, max:    0.620, cur:    0.017)
# dice_coef
# 	training         	 (min:    0.017, max:    0.770, cur:    0.765)
# 	validation       	 (min:    0.000, max:    0.750, cur:    0.736)
# Loss
# 	training         	 (min:    0.230, max:    0.983, cur:    0.236)
# 	validation       	 (min:    0.253, max:    1.000, cur:    0.266)
# 67/67 [==============================] - 348s 5s/step - loss: 0.2362 - binary_crossentropy: 0.0179 - dice_coef: 0.7645 - val_loss: 0.2661 - val_binary_crossentropy: 0.0166 - val_dice_coef: 0.7362
# ------------------------------
# Training finished
# ------------------------------

# %%
EPOCHS = 100
os.environ["CUDA_VISIBLE_DEVICES"]='0'
PROJECT_NAME = '3dDenseUnet_dropout_augmentation'
train(att_input= False)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.016, max:    0.727, cur:    0.016)
# 	validation       	 (min:    0.014, max:    0.635, cur:    0.018)
# dice_coef
# 	training         	 (min:    0.017, max:    0.825, cur:    0.810)
# 	validation       	 (min:    0.000, max:    0.756, cur:    0.752)
# Loss
# 	training         	 (min:    0.174, max:    0.983, cur:    0.190)
# 	validation       	 (min:    0.247, max:    1.000, cur:    0.252)
# 67/67 [==============================] - 343s 5s/step - loss: 0.1904 - binary_crossentropy: 0.0158 - dice_coef: 0.8101 - val_loss: 0.2515 - val_binary_crossentropy: 0.0181 - val_dice_coef: 0.7516
# ------------------------------
# Training finished
# ------------------------------

# %%
EPOCHS = 100

os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_dropout_elastic_augmentation.h5'
train(att_input= False, inter_channel = 1, loss_function= dice_coef_loss, retrain = PROJECT_NAME)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.012, max:    0.644, cur:    0.018)
# 	validation       	 (min:    0.014, max:    0.644, cur:    0.017)
# dice_coef
# 	training         	 (min:    0.000, max:    0.873, cur:    0.786)
# 	validation       	 (min:    0.000, max:    0.772, cur:    0.755)
# Loss
# 	training         	 (min:    0.127, max:    1.000, cur:    0.215)
# 	validation       	 (min:    0.232, max:    1.000, cur:    0.248)
# lr
# 	lr               	 (min:    0.000, max:    0.000, cur:    0.000)
# 67/67 [==============================] - 364s 5s/step - loss: 0.2148 - binary_crossentropy: 0.0177 - dice_coef: 0.7858 - val_loss: 0.2484 - val_binary_crossentropy: 0.0170 - val_dice_coef: 0.7551 - lr: 1.0000e-04
# Epoch 14/100
# 40/67 [================>.............] - ETA: 2:01 - loss: 0.2244 - binary_crossentropy: 0.0178 - dice_coef: 0.7756
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1c971831b754> in <module>
#       3 os.environ["CUDA_VISIBLE_DEVICES"]='1'
#       4 PROJECT_NAME = '3dDenseUnet_dropout_elastic_augmentation.h5'
# ----> 5 train(att_input= False, inter_channel = 1, loss_function= dice_coef_loss, retrain = PROJECT_NAME)
#
# <ipython-input-33-5b9c33c04d6e> in train(att_input, inter_channel, loss_function, retrain, L2)
#      94     model.fit(train_dataset, validation_data = valid_dataset, steps_per_epoch = steps_per_epoch,
#      95          validation_steps = validation_steps, epochs = EPOCHS, callbacks=[model_checkpoint,reduce_lr, csv_logger,PlotLossesKerasTF()],
# ---> 96              verbose = 1)
#      97
#      98     print('-'*30)
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
EPOCHS = 50
os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_dropout_elas_aug_window'
train(att_input= False, loss_function= dice_coef_loss,retrain = PROJECT_NAME)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.010, max:    0.708, cur:    0.106)
# 	validation       	 (min:    0.011, max:    0.709, cur:    0.018)
# dice_coef
# 	training         	 (min:    0.000, max:    0.873, cur:    0.700)
# 	validation       	 (min:    0.000, max:    0.774, cur:    0.770)
# Loss
# 	training         	 (min:    0.127, max:    1.320, cur:    0.302)
# 	validation       	 (min:    0.229, max:    1.032, cur:    0.233)
# lr
# 	lr               	 (min:    0.000, max:    0.001, cur:    0.000)
# 70/70 [==============================] - 334s 5s/step - loss: 0.3016 - binary_crossentropy: 0.1062 - dice_coef: 0.7001 - val_loss: 0.2331 - val_binary_crossentropy: 0.0181 - val_dice_coef: 0.7702 - lr: 6.4793e-06
# Epoch 46/50
# 48/70 [===================>..........] - ETA: 1:26 - loss: 0.1190 - binary_crossentropy: 0.0108 - dice_coef: 0.8810
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-225-3706cb451c5a> in <module>
#       2 os.environ["CUDA_VISIBLE_DEVICES"]='1'
#       3 PROJECT_NAME = '3dDenseUnet_dropout_elas_aug_window'
# ----> 4 train(att_input= False, loss_function= dice_coef_loss,retrain = PROJECT_NAME)
#
# <ipython-input-224-dfd26ba1dbb9> in train(att_input, inter_channel, loss_function, retrain, L2)
#     130     model.fit(train_dataset, validation_data = valid_dataset, steps_per_epoch = steps_per_epoch,
#     131          validation_steps = validation_steps, epochs = EPOCHS, callbacks=[model_checkpoint,reduce_lr,lr_finder,scheduler, csv_logger,PlotLossesKerasTF()],
# --> 132              verbose = 1)
#     133
#     134     print('-'*30)
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
EPOCHS = 50
os.environ["CUDA_VISIBLE_DEVICES"]='1'
PROJECT_NAME = '3dDenseUnet_dropout_elas_aug_window'
train(att_input= False, loss_function= dice_coef_loss,retrain = PROJECT_NAME)
# Out:
# binary_crossentropy
# 	training         	 (min:    0.010, max:    0.708, cur:    0.029)
# 	validation       	 (min:    0.011, max:    0.709, cur:    0.018)
# dice_coef
# 	training         	 (min:    0.000, max:    0.873, cur:    0.628)
# 	validation       	 (min:    0.000, max:    0.779, cur:    0.774)
# Loss
# 	training         	 (min:    0.127, max:    1.320, cur:    0.366)
# 	validation       	 (min:    0.224, max:    1.032, cur:    0.228)
# lr
# 	lr               	 (min:    0.000, max:    0.001, cur:    0.000)
# 75/75 [==============================] - 366s 5s/step - loss: 0.3660 - binary_crossentropy: 0.0290 - dice_coef: 0.6284 - val_loss: 0.2285 - val_binary_crossentropy: 0.0183 - val_dice_coef: 0.7744 - lr: 9.3921e-08
# Epoch 43/50
# 24/75 [========>.....................] - ETA: 3:15 - loss: 0.0990 - binary_crossentropy: 0.0095 - dice_coef: 0.9010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-3706cb451c5a> in <module>
#       2 os.environ["CUDA_VISIBLE_DEVICES"]='1'
#       3 PROJECT_NAME = '3dDenseUnet_dropout_elas_aug_window'
# ----> 4 train(att_input= False, loss_function= dice_coef_loss,retrain = PROJECT_NAME)
#
# <ipython-input-241-402081037dc4> in train(att_input, inter_channel, loss_function, retrain, L2)
#     130     model.fit(train_dataset, validation_data = valid_dataset, steps_per_epoch = steps_per_epoch,
#     131          validation_steps = validation_steps, epochs = EPOCHS, callbacks=[model_checkpoint,reduce_lr,lr_finder,scheduler, csv_logger,PlotLossesKerasTF()],
# --> 132              verbose = 1)
#     133
#     134     print('-'*30)
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
